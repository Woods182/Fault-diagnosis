# %%
import os
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import layers, models
# 查看GPU是否可用
print(tf.test.is_gpu_available())
# Out:
# WARNING:tensorflow:From <ipython-input-1-763a6c7e3bd0>:10: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
from sklearn.preprocessing import scale
def load_data(data_name,label_name):
    path_x=data_name
    path_y=label_name
    # 读取数据
    x = np.load(path_x)
#     scaler = MinMaxScaler()
#      x = scaler.fit_transform(x)
    x=scale(x)
    y = np.load(path_y)
    num = len(Counter(y))
    print("类别数量为：", num)
    return x, y, num

# %%
def create_train_data(x, y, ratio=0.7):
    """
    x:data
    y:labal
    ratio:生成训练集比率
    """
    # 打乱顺序
    # 读取data矩阵的第一维数（数据个数）
    num_example = x.shape[0]
    # 产生一个num_example范围，步长为1的序列
    arr = np.arange(num_example)
    # 调用函数，打乱顺序
    np.random.seed(99)
    np.random.shuffle(arr)
    # 按照打乱的顺序，重新排序
    arr_data = x[arr]
    arr_label = y[arr]
    # 将数据集分为训练集80%、测试集20%
    s = int(num_example * ratio)
    x_train = arr_data[:s]
    y_train = arr_label[:s]
    x_val = arr_data[s:]
    y_val = arr_label[s:]
    print("训练集shape", x_train.shape)
    print("训练集类别：", Counter(y_train))
    print("测试集shape", x_val.shape)
    print("测试集类别：", Counter(y_val))
    return x_train, y_train, x_val, y_val

# %%
# 读取数据
data, label, label_count= load_data('train_data_wavelet.npy','label_wavelet.npy')
# 生成训练集测试集,70%用作训练，30%用作测试
train_data, train_label, val_data, val_label= create_train_data(data, label, 0.8)
print("*"*10)
print("训练集数量：",len(train_label))
print("测试集数量：",len(val_label))
# Out:
# 类别数量为： 4
# 训练集shape (3753, 2014)
# 训练集类别： Counter({1: 995, 0: 950, 2: 941, 3: 867})
# 测试集shape (939, 2014)
# 测试集类别： Counter({1: 241, 2: 239, 0: 230, 3: 229})
# **********
# 训练集数量： 3753
# 测试集数量： 939

# %% [markdown]
# # 模型优化

# %%
from tensorflow.keras.layers import  LSTM,Bidirectional

# %%
def cnnbilstm_optimize1():
    loss = 'sparse_categorical_crossentropy'
    metrics = ['acc']
    inputs = keras.Input(shape=(2014,1))
    #CNN+POOLING
    x = layers.Conv1D(128, 3, activation='relu')(inputs)
    x = layers.Conv1D(128, 3, activation='relu')(x)
    x = layers.MaxPooling1D(16)(x)
    x = layers.Conv1D(64, 3, activation='relu')(x)
    x = layers.MaxPooling1D(16)(x)
    #BiLSTM
    #x=Bidirectional(LSTM(128,return_sequences=True))(x)
    x=Bidirectional(LSTM(128))(x)
    outputs = layers.Dense(4, activation='softmax')(x)
    model = keras.Model(inputs, outputs)
    model.compile(optimizer='rmsprop',
                  loss=loss,
                  metrics=metrics)
    print("实例化模型成功，参数如下：")
    print(model.summary())
    return model

# %%
# 实例化模型
cnnbilstm_model = cnnbilstm_optimize1()

# 设置模型log输出地址
log_dir = os.path.join("logs/optimize1")
if not os.path.exists(log_dir):
    os.mkdir(log_dir)
# Out:
# 实例化模型成功，参数如下：
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2014, 1)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 2012, 128)         512
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2010, 128)         49280
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 125, 128)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 123, 64)           24640
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 7, 64)             0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 256)               197632
# _________________________________________________________________
# dense (Dense)                (None, 4)                 1028
# =================================================================
# Total params: 273,092
# Trainable params: 273,092
# Non-trainable params: 0
# _________________________________________________________________
# None
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-82f0b036967f> in <module>
#       5 log_dir = os.path.join("logs/optimize1")
#       6 if not os.path.exists(log_dir):
# ----> 7     os.mkdir(log_dir)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'logs/optimize1'

# %%
# 模型训练
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
history = cnnbilstm_model.fit(train_data, train_label,epochs=30, batch_size=32, validation_split=0.2,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/30
# 94/94 [==============================] - 12s 41ms/step - loss: 0.5448 - acc: 0.7002 - val_loss: 0.6040 - val_acc: 0.6991
# Epoch 2/30
# 94/94 [==============================] - 2s 21ms/step - loss: 0.3636 - acc: 0.7795 - val_loss: 0.3082 - val_acc: 0.8229
# Epoch 3/30
# 94/94 [==============================] - 2s 16ms/step - loss: 0.3238 - acc: 0.8248 - val_loss: 0.2857 - val_acc: 0.8429
# Epoch 4/30
# 94/94 [==============================] - 1s 13ms/step - loss: 0.2946 - acc: 0.8384 - val_loss: 0.2890 - val_acc: 0.8296
# Epoch 5/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.2924 - acc: 0.8461 - val_loss: 0.2794 - val_acc: 0.8549
# Epoch 6/30
# 94/94 [==============================] - 2s 19ms/step - loss: 0.2772 - acc: 0.8491 - val_loss: 0.2771 - val_acc: 0.8602
# Epoch 7/30
# 94/94 [==============================] - 2s 17ms/step - loss: 0.2774 - acc: 0.8578 - val_loss: 0.2596 - val_acc: 0.8668
# Epoch 8/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.2670 - acc: 0.8601 - val_loss: 0.2840 - val_acc: 0.8389
# Epoch 9/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.2660 - acc: 0.8638 - val_loss: 0.2693 - val_acc: 0.8415
# Epoch 10/30
# 94/94 [==============================] - 2s 18ms/step - loss: 0.2514 - acc: 0.8654 - val_loss: 0.2401 - val_acc: 0.8842
# Epoch 11/30
# 94/94 [==============================] - 2s 17ms/step - loss: 0.2234 - acc: 0.8964 - val_loss: 0.1643 - val_acc: 0.9467
# Epoch 12/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.1890 - acc: 0.9071 - val_loss: 0.2086 - val_acc: 0.8881
# Epoch 13/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.1716 - acc: 0.9304 - val_loss: 0.1437 - val_acc: 0.9427
# Epoch 14/30
# 94/94 [==============================] - 2s 18ms/step - loss: 0.1452 - acc: 0.9344 - val_loss: 0.1061 - val_acc: 0.9507
# Epoch 15/30
# 94/94 [==============================] - 2s 17ms/step - loss: 0.1273 - acc: 0.9500 - val_loss: 0.0650 - val_acc: 0.9774
# Epoch 16/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.1210 - acc: 0.9477 - val_loss: 0.0949 - val_acc: 0.9507
# Epoch 17/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.1104 - acc: 0.9524 - val_loss: 0.2462 - val_acc: 0.9015
# Epoch 18/30
# 94/94 [==============================] - 2s 19ms/step - loss: 0.1177 - acc: 0.9564 - val_loss: 0.1221 - val_acc: 0.9454
# Epoch 19/30
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0934 - acc: 0.9617 - val_loss: 0.1065 - val_acc: 0.9494
# Epoch 20/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0990 - acc: 0.9637 - val_loss: 0.0623 - val_acc: 0.9720
# Epoch 21/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0920 - acc: 0.9667 - val_loss: 0.1120 - val_acc: 0.9414
# Epoch 22/30
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0829 - acc: 0.9657 - val_loss: 0.0487 - val_acc: 0.9920
# Epoch 23/30
# 94/94 [==============================] - 2s 15ms/step - loss: 0.0923 - acc: 0.9690 - val_loss: 0.0986 - val_acc: 0.9534
# Epoch 24/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0838 - acc: 0.9700 - val_loss: 0.0759 - val_acc: 0.9614
# Epoch 25/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0874 - acc: 0.9700 - val_loss: 0.0389 - val_acc: 0.9907
# Epoch 26/30
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0751 - acc: 0.9734 - val_loss: 0.0379 - val_acc: 0.9854
# Epoch 27/30
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0752 - acc: 0.9724 - val_loss: 0.0375 - val_acc: 0.9893
# Epoch 28/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0682 - acc: 0.9727 - val_loss: 0.0337 - val_acc: 0.9920
# Epoch 29/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0625 - acc: 0.9724 - val_loss: 0.0640 - val_acc: 0.9707
# Epoch 30/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0540 - acc: 0.9797 - val_loss: 0.0352 - val_acc: 0.9867

# %%
from sklearn.metrics import roc_curve,roc_auc_score,classification_report,accuracy_score,log_loss
print("*****完成预处理，进行模型评估*****")
y_pred = cnnbilstm_model.predict(val_data)
y_pred = [np.argmax(x) for x in y_pred]
print('------------------测试集上得分：------------------------')
print('*' * 5)
print('测试集准确率得分:', round(accuracy_score(val_label, y_pred),3))
print('*' * 5)
print('准确率、召回率、f1-值测试报告如下:\n', classification_report(val_label, y_pred))
# Out:
# *****完成预处理，进行模型评估*****
# ------------------测试集上得分：------------------------
# *****
# 测试集准确率得分: 0.985
# *****
# 准确率、召回率、f1-值测试报告如下:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       230
#            1       0.95      1.00      0.97       241
#            2       1.00      0.94      0.97       239
#            3       1.00      1.00      1.00       229
#
#     accuracy                           0.99       939
#    macro avg       0.99      0.99      0.99       939
# weighted avg       0.99      0.99      0.99       939

# %%
# 设置Y轴范围
plt.ylim(0.3,1)
# 训练准确率曲线
show_data1_cnnbilstm= history.history['acc']
# 测试准确率曲线
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
show_data2_cnnbilstm= history.history['val_acc']
x_data = list(range(1,len(show_data1_cnnbilstm)+1))
ln1, = plt.plot(x_data,show_data1_cnnbilstm,color='blue',linewidth=2.0,linestyle='--')
ln2, = plt.plot(x_data,show_data2_cnnbilstm,color='red',linewidth=3.0,linestyle='-.')
plt.legend(handles=[ln1,ln2],labels=['train','val'])
plt.show()

# %%
#loss曲线
# 设置Y轴范围
#plt.ylim(0.3,1)
# 训练准确率曲线
show_data1_cnnbilstm= history.history['loss']
# 测试准确率曲线
plt.ylabel("Loss")
plt.xlabel("Epoch")
show_data2_cnnbilstm= history.history['val_loss']
x_data = list(range(1,len(show_data1_cnnbilstm)+1))
ln1, = plt.plot(x_data,show_data1_cnnbilstm,color='blue',linewidth=2.0,linestyle='--')
ln2, = plt.plot(x_data,show_data2_cnnbilstm,color='red',linewidth=3.0,linestyle='-.')
plt.legend(handles=[ln1,ln2],labels=['train','val'])
plt.show()

# %% [markdown]
# # 可视化

# %%
from  tensorflow.keras.models import Model
from sklearn import manifold
import matplotlib as mpl

# %%
img_size=2014
color = train_label
#color = [np.argmax(i) for i in color] #将one-hot编码转换为整数
#color = np.stack(color, axis=0)

n_neighbors = 4   #一共有多少个类别
n_components = 2  #降维成几维 2或者3

# %%
print(train_label)
print(type(train_label))
# Out:
# [1 2 2 ... 0 0 2]
# <class 'numpy.ndarray'>

# %%
def colormap():
    return mpl.colors.LinearSegmentedColormap.from_list \
        ('cmap', ['#8B0000', '#FF6A6A', '#00FF00', '#F4A460'], 256)
        #('cmap', ['#FFFFFF', '#98F5FF', '#00FF00', '#FFFF00','#FF0000', '#8B0000'], 256) #white, CadetBlue1, Green1, Yellow1, Red,DarkRed

#cm = plt.cm.Spectral
cm = colormap()
#颜色选取

# %%
plt.rcParams['font.sans-serif']=['SimHei'] #显示中文标签
plt.rcParams['axes.unicode_minus']=False 
color_list = ['#8B0000', '#FF6A6A', '#00FF00', '#F4A460']

# %% [markdown]
# ## 原始数据

# %%
# 创建自定义图像
fig = plt.figure()
#plt.suptitle("Dimensionality Reduction and Visualization of surface-defect Data ", fontsize=14)		# 自定义图像名称

# t-SNE对原始图像的降维与可视化
ts = manifold.TSNE(n_components=n_components, init='pca', random_state=0)
# 训练模型
test_data =train_data.reshape((len(train_data), img_size))
y = ts.fit_transform(test_data)
ax1 = fig.add_subplot(1, 1, 1)
for i in range(len(color)):# 将标签号和每个类的画法进行对应。
    if color[i] == 0:
        s0 = plt.scatter(y[i, 0], y[i, 1], c=color_list[0], cmap=cm, s=2)
    elif color[i] == 1:
        s1 = plt.scatter(y[i, 0], y[i, 1], c=color_list[1], cmap=cm, s=2)
    elif color[i] == 2:
        s2 = plt.scatter(y[i, 0], y[i, 1], c=color_list[2], cmap=cm, s=2)
    elif color[i] == 3:
        s3 = plt.scatter(y[i, 0], y[i, 1], c=color_list[3], cmap=cm, s=2)
plt.legend((s0,s1,s2,s3),('轴承故障','不平衡','正常数据','风扇缺相') ,loc = 'best')#添加图例
# 显示图像
plt.show()

# %% [markdown]
# ## 卷积层1

# %%
conv1d_1_layer_model = Model(inputs=cnnbilstm_model.input,outputs=cnnbilstm_model.get_layer('conv1d').output)
out_conv1d_1= conv1d_1_layer_model.predict(train_data)
print(out_conv1d_1.shape)
# Out:
# (3753, 2012, 128)

# %%
# 创建自定义图像
fig = plt.figure()
#plt.suptitle("Dimensionality Reduction and Visualization of surface-defect Data ", fontsize=14)		# 自定义图像名称

# t-SNE对原始图像的降维与可视化
ts = manifold.TSNE(n_components=n_components, init='pca', random_state=0)
# 训练模型
out_conv1d_1 =out_conv1d_1.reshape(3753, -1)
y = ts.fit_transform(out_conv1d_1)
ax1 = fig.add_subplot(1, 1, 1)
for i in range(len(color)):# 将标签号和每个类的画法进行对应。
    if color[i] == 0:
        s0 = plt.scatter(y[i, 0], y[i, 1], c=color_list[0], cmap=cm, s=2)
    elif color[i] == 1:
        s1 = plt.scatter(y[i, 0], y[i, 1], c=color_list[1], cmap=cm, s=2)
    elif color[i] == 2:
        s2 = plt.scatter(y[i, 0], y[i, 1], c=color_list[2], cmap=cm, s=2)
    elif color[i] == 3:
        s3 = plt.scatter(y[i, 0], y[i, 1], c=color_list[3], cmap=cm, s=2)
plt.legend((s0,s1,s2,s3),('轴承故障','不平衡','正常数据','风扇缺相') ,loc = 'best')#添加图例
# 显示图像
plt.show()

# %% [markdown]
# ## 卷积层2

# %%
conv1d_2_layer_model = Model(inputs=cnnbilstm_model.input,outputs=cnnbilstm_model.get_layer('conv1d_1').output)
out_conv1d_2= conv1d_2_layer_model.predict(train_data)
print(out_conv1d_2.shape)
# Out:
# (3753, 2010, 128)

# %%
# 创建自定义图像
fig = plt.figure()
#plt.suptitle("Dimensionality Reduction and Visualization of surface-defect Data ", fontsize=14)		# 自定义图像名称

# t-SNE对原始图像的降维与可视化
ts = manifold.TSNE(n_components=n_components, init='pca', random_state=0)
# 训练模型
out_conv1d_2 =out_conv1d_2.reshape(3753, -1)
y = ts.fit_transform(out_conv1d_2)
ax1 = fig.add_subplot(1, 1, 1)
for i in range(len(color)):# 将标签号和每个类的画法进行对应。
    if color[i] == 0:
        s0 = plt.scatter(y[i, 0], y[i, 1], c=color_list[0], cmap=cm, s=2)
    elif color[i] == 1:
        s1 = plt.scatter(y[i, 0], y[i, 1], c=color_list[1], cmap=cm, s=2)
    elif color[i] == 2:
        s2 = plt.scatter(y[i, 0], y[i, 1], c=color_list[2], cmap=cm, s=2)
    elif color[i] == 3:
        s3 = plt.scatter(y[i, 0], y[i, 1], c=color_list[3], cmap=cm, s=2)
plt.legend((s0,s1,s2,s3),('轴承故障','不平衡','正常数据','风扇缺相') ,loc = 'best')#添加图例
# 显示图像
plt.show()

# %% [markdown]
# ## 池化1

# %%
pooling_layer_model = Model(inputs=cnnbilstm_model.input,outputs=cnnbilstm_model.get_layer('max_pooling1d').output)
out_pooling= pooling_layer_model.predict(train_data)
print(out_pooling.shape)
# Out:
# (3753, 125, 128)

# %%
# 创建自定义图像
fig = plt.figure()
#plt.suptitle("Dimensionality Reduction and Visualization of surface-defect Data ", fontsize=14)		# 自定义图像名称

# t-SNE对原始图像的降维与可视化
ts = manifold.TSNE(n_components=n_components, init='pca', random_state=0)
# 训练模型
out_pooling =out_pooling.reshape(3753, -1)
y = ts.fit_transform(out_pooling)
ax1 = fig.add_subplot(1, 1, 1)
for i in range(len(color)):# 将标签号和每个类的画法进行对应。
    if color[i] == 0:
        s0 = plt.scatter(y[i, 0], y[i, 1], c=color_list[0], cmap=cm, s=2)
    elif color[i] == 1:
        s1 = plt.scatter(y[i, 0], y[i, 1], c=color_list[1], cmap=cm, s=2)
    elif color[i] == 2:
        s2 = plt.scatter(y[i, 0], y[i, 1], c=color_list[2], cmap=cm, s=2)
    elif color[i] == 3:
        s3 = plt.scatter(y[i, 0], y[i, 1], c=color_list[3], cmap=cm, s=2)
plt.legend((s0,s1,s2,s3),('轴承故障','不平衡','正常数据','风扇缺相') ,loc = 'best')#添加图例
# 显示图像
plt.show()

# %% [markdown]
# ## cnn3

# %%
conv1d_3_layer_model = Model(inputs=cnnbilstm_model.input,outputs=cnnbilstm_model.get_layer('conv1d_2').output)
out_conv1d_3= conv1d_3_layer_model.predict(train_data)
print(out_conv1d_3.shape)
# Out:
# (3753, 123, 64)

# %%
# 创建自定义图像
fig = plt.figure()
#plt.suptitle("Dimensionality Reduction and Visualization of surface-defect Data ", fontsize=14)		# 自定义图像名称

# t-SNE对原始图像的降维与可视化
ts = manifold.TSNE(n_components=n_components, init='pca', random_state=0)
# 训练模型
out_conv1d_3 =out_conv1d_3.reshape(3753, -1)
y = ts.fit_transform(out_conv1d_3)
ax1 = fig.add_subplot(1, 1, 1)
for i in range(len(color)):# 将标签号和每个类的画法进行对应。
    if color[i] == 0:
        s0 = plt.scatter(y[i, 0], y[i, 1], c=color_list[0], cmap=cm, s=2)
    elif color[i] == 1:
        s1 = plt.scatter(y[i, 0], y[i, 1], c=color_list[1], cmap=cm, s=2)
    elif color[i] == 2:
        s2 = plt.scatter(y[i, 0], y[i, 1], c=color_list[2], cmap=cm, s=2)
    elif color[i] == 3:
        s3 = plt.scatter(y[i, 0], y[i, 1], c=color_list[3], cmap=cm, s=2)
plt.legend((s0,s1,s2,s3),('轴承故障','不平衡','正常数据','风扇缺相') ,loc = 'best')#添加图例
# 显示图像
plt.show()

# %% [markdown]
# ## 池化2

# %%
pooling2_layer_model = Model(inputs=cnnbilstm_model.input,outputs=cnnbilstm_model.get_layer('max_pooling1d_1').output)
out_pooling2= pooling2_layer_model.predict(train_data)
print(out_pooling2.shape)
# Out:
# (3753, 7, 64)

# %%
# 创建自定义图像
fig = plt.figure()
#plt.suptitle("Dimensionality Reduction and Visualization of surface-defect Data ", fontsize=14)		# 自定义图像名称

# t-SNE对原始图像的降维与可视化
ts = manifold.TSNE(n_components=n_components, init='pca', random_state=0)
# 训练模型
out_pooling2 =out_pooling2.reshape(3753, -1)
y = ts.fit_transform(out_pooling2)
ax1 = fig.add_subplot(1, 1, 1)
for i in range(len(color)):# 将标签号和每个类的画法进行对应。
    if color[i] == 0:
        s0 = plt.scatter(y[i, 0], y[i, 1], c=color_list[0], cmap=cm, s=2)
    elif color[i] == 1:
        s1 = plt.scatter(y[i, 0], y[i, 1], c=color_list[1], cmap=cm, s=2)
    elif color[i] == 2:
        s2 = plt.scatter(y[i, 0], y[i, 1], c=color_list[2], cmap=cm, s=2)
    elif color[i] == 3:
        s3 = plt.scatter(y[i, 0], y[i, 1], c=color_list[3], cmap=cm, s=2)
plt.legend((s0,s1,s2,s3),('轴承故障','不平衡','正常数据','风扇缺相') ,loc = 'best')#添加图例
# 显示图像
plt.show()

# %% [markdown]
# ## BiLSTM

# %%
bilstm_layer_model = Model(inputs=cnnbilstm_model.input,outputs=cnnbilstm_model.get_layer('bidirectional').output)
out_bilstm= bilstm_layer_model.predict(train_data)
print(out_bilstm.shape)
# Out:
# (3753, 256)

# %%
# 创建自定义图像
fig = plt.figure()
#plt.suptitle("Dimensionality Reduction and Visualization of surface-defect Data ", fontsize=14)		# 自定义图像名称

# t-SNE对原始图像的降维与可视化
ts = manifold.TSNE(n_components=n_components, init='pca', random_state=0)
# 训练模型
out_bilstm =out_bilstm.reshape(3753, -1)
y = ts.fit_transform(out_bilstm)
ax1 = fig.add_subplot(1, 1, 1)
for i in range(len(color)):# 将标签号和每个类的画法进行对应。
    if color[i] == 0:
        s0 = plt.scatter(y[i, 0], y[i, 1], c=color_list[0], cmap=cm, s=2)
    elif color[i] == 1:
        s1 = plt.scatter(y[i, 0], y[i, 1], c=color_list[1], cmap=cm, s=2)
    elif color[i] == 2:
        s2 = plt.scatter(y[i, 0], y[i, 1], c=color_list[2], cmap=cm, s=2)
    elif color[i] == 3:
        s3 = plt.scatter(y[i, 0], y[i, 1], c=color_list[3], cmap=cm, s=2)
plt.legend((s0,s1,s2,s3),('轴承故障','不平衡','正常数据','风扇缺相') ,loc = 'best')#添加图例
# 显示图像
plt.show()

# %% [markdown]
# ## 输出层

# %%
dense_layer_model = Model(inputs=cnnbilstm_model.input,outputs=cnnbilstm_model.get_layer('dense').output)
out_dense= dense_layer_model.predict(train_data)
print(out_dense.shape)
# Out:
# (3753, 4)

# %%
# 创建自定义图像
fig = plt.figure()
#plt.suptitle("Dimensionality Reduction and Visualization of surface-defect Data ", fontsize=14)		# 自定义图像名称

# t-SNE对原始图像的降维与可视化
ts = manifold.TSNE(n_components=n_components, init='pca', random_state=0)
# 训练模型
out_bilstm =out_dense.reshape(3753, -1)
y = ts.fit_transform(out_dense)
ax1 = fig.add_subplot(1, 1, 1)
for i in range(len(color)):# 将标签号和每个类的画法进行对应。
    if color[i] == 0:
        s0 = plt.scatter(y[i, 0], y[i, 1], c=color_list[0], cmap=cm, s=2)
    elif color[i] == 1:
        s1 = plt.scatter(y[i, 0], y[i, 1], c=color_list[1], cmap=cm, s=2)
    elif color[i] == 2:
        s2 = plt.scatter(y[i, 0], y[i, 1], c=color_list[2], cmap=cm, s=2)
    elif color[i] == 3:
        s3 = plt.scatter(y[i, 0], y[i, 1], c=color_list[3], cmap=cm, s=2)
plt.legend((s0,s1,s2,s3),('轴承故障','不平衡','正常数据','风扇缺相') ,loc = 'best')#添加图例
# 显示图像
plt.show()
